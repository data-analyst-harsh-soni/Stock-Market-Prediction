# %%
import numpy as np 
import pandas as pd

# %%
BASE_PATH = r"D:\DATA_ANALYST\FULL_STACK_FROJECT\Stock Market Prediction\stock_market_unclean_dataset"
df = pd.read_csv(BASE_PATH + r"\metadata\data_dictionary.csv")

# %%
df.head()
# Out:
#             column                     description
# 0             open          Opening price of stock
# 1            close          Closing price of stock
# 2  sentiment_score  News sentiment score (-1 to 1)
# 3        inflation            Inflation percentage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   column       4 non-null      object
#  1   description  4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df['column'] = df['column'].str.strip().str.lower()
df['description'] = df['description'].str.strip()

# %%
df.rename(columns={'column': 'feature_name', 'description': 'feature_description'}, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#       feature_name             feature_description
# 0             open          Opening price of stock
# 1            close          Closing price of stock
# 2  sentiment_score  News sentiment score (-1 to 1)
# 3        inflation            Inflation percentage

# %%
df = df[["feature_name","feature_description"]]

# %%
df.to_csv("data_dictionary.csv", index=False)
